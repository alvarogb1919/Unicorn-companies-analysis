# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
unicorns = pd.read_csv("./data/unicorns.csv")

# %%
unicorns
# Out:
#        Company name Valuation (in $B) Date Joined Country of origin  \
# 0         Bytedance              $140  04-07-2017             China
# 1            Stripe               $95   1/23/2014     United States
# 2            SpaceX               $74  12-01-2012     United States
# 3      Didi Chuxing               $62   3/31/2015             China
# 4            Klarna             $45.6  12-12-2011            Sweden
# ..              ...               ...         ...               ...
# 703          Shippo                $1  06-02-2021     United States
# 704  Thirty Madison                $1  06-02-2021     United States
# 705  LetsGetChecked                $1  06-07-2021           Ireland
# 706          VerbIT                $1  06-08-2021            Israel
# 707            Aura                $1  06-09-2021     United States
#
#               City                             Industry  \
# 0          Beijing              Artificial intelligence
# ...

# %%
unicorns.sample(5)
# Out:
#     Company name Valuation (in $B) Date Joined Country of origin  \
# 697       Axtria                $1   5/13/2021     United States
# 90    Magic Leap             $4.82  10/21/2014     United States
# 276      Tipalti                $2  10-06-2020     United States
# 443    Outschool              $1.3   4/14/2021     United States
# 449  KeepTruckin             $1.25   4/23/2019     United States
#
#                 City                             Industry  \
# 697  Berkeley Height          Data management & analytics
# 90        Plantation                             Hardware
# 276        San Mateo                              Fintech
# 443    San Francisco                               Edtech
# 449    San Francisco  Supply chain, logistics, & delivery
#
#                                              Investors
# 697  Helion Venture Partners, Bain Capital Tech Opp...
# 90   Obvious Ventures, Qualcomm Ventures, Andreesse...
# 276               01 Advisors, Zeev Ventures, Group 11
# ...

# %%
unicorn_columns = {"Company name" : "Company_name", "Valuation (in $B)" : "Valuation_usd_bn", "Date Joined" : "Founding_date", "Country of origin" : "Country", "City" : "City", "Industry" : "Industry", "Investors" : "Investors"}

# %%
unicorns.rename(columns = unicorn_columns, inplace = True)

# %%
unicorns.head()
# Out:
#    Company_name Valuation_usd_bn Founding_date        Country           City  \
# 0     Bytedance             $140    04-07-2017          China        Beijing
# 1        Stripe              $95     1/23/2014  United States  San Francisco
# 2        SpaceX              $74    12-01-2012  United States      Hawthorne
# 3  Didi Chuxing              $62     3/31/2015          China        Beijing
# 4        Klarna            $45.6    12-12-2011         Sweden      Stockholm
#
#                   Industry                                          Investors
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...

# %%
unicorns.columns
# Out:
# Index(['Company_name', 'Valuation_usd_bn', 'Founding_date', 'Country', 'City',
#        'Industry', 'Investors'],
#       dtype='object')

# %%
unicorns.dtypes
# Out:
# Company_name        object
# Valuation_usd_bn    object
# Founding_date       object
# Country             object
# City                object
# Industry            object
# Investors           object
# dtype: object

# %%
unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company_name      708 non-null    object
#  1   Valuation_usd_bn  708 non-null    object
#  2   Founding_date     708 non-null    object
#  3   Country           708 non-null    object
#  4   City              699 non-null    object
#  5   Industry          708 non-null    object
#  6   Investors         707 non-null    object
# dtypes: object(7)
# memory usage: 38.8+ KB

# %%
from datetime import datetime

# %%
my_string = '1/23/2014'

# %%
my_date = datetime.strptime(my_string, "%m/%d/%Y")

# %%
print(my_date)
# Out:
# 2014-01-23 00:00:00

# %%
z = "04-07-2017"

# %%
z.replace("-", "/")
# Out:
# '04/07/2017'

# %%
def date_year(date):
    first_clean = date.replace("-", "/")
    second_clean = datetime.strptime(first_clean, "%m/%d/%Y")
    return second_clean.year

# %%
date_year("5-24-2015")
# Out:
# 2015

# %%
unicorns["Year_founded"] = unicorns["Founding_date"].apply(date_year)

# %%
unicorns.head()
# Out:
#    Company_name Valuation_usd_bn Founding_date        Country           City  \
# 0     Bytedance             $140    04-07-2017          China        Beijing
# 1        Stripe              $95     1/23/2014  United States  San Francisco
# 2        SpaceX              $74    12-01-2012  United States      Hawthorne
# 3  Didi Chuxing              $62     3/31/2015          China        Beijing
# 4        Klarna            $45.6    12-12-2011         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded
# 0          2017
# ...

# %%
unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company_name      708 non-null    object
#  1   Valuation_usd_bn  708 non-null    object
#  2   Founding_date     708 non-null    object
#  3   Country           708 non-null    object
#  4   City              699 non-null    object
#  5   Industry          708 non-null    object
#  6   Investors         707 non-null    object
#  7   Year_founded      708 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 44.4+ KB

# %%
unicorns.drop(["Founding_date"], axis = 1, inplace = True)

# %%
unicorns.head()
# Out:
#    Company_name Valuation_usd_bn        Country           City  \
# 0     Bytedance             $140          China        Beijing
# 1        Stripe              $95  United States  San Francisco
# 2        SpaceX              $74  United States      Hawthorne
# 3  Didi Chuxing              $62          China        Beijing
# 4        Klarna            $45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded
# 0          2017
# 1          2014
# 2          2012
# 3          2015
# 4          2011

# %%
def clean_valuation(valuation):
    return float(valuation.replace("$", ""))

# %%
clean_valuation("$253.4")
# Out:
# 253.4

# %%
unicorns["Valuation_usd_bn"] = unicorns["Valuation_usd_bn"].apply(clean_valuation)

# %%
unicorns.head()
# Out:
#    Company_name  Valuation_usd_bn        Country           City  \
# 0     Bytedance             140.0          China        Beijing
# 1        Stripe              95.0  United States  San Francisco
# 2        SpaceX              74.0  United States      Hawthorne
# 3  Didi Chuxing              62.0          China        Beijing
# 4        Klarna              45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded
# 0          2017
# 1          2014
# 2          2012
# 3          2015
# 4          2011

# %%
unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company_name      708 non-null    object
#  1   Valuation_usd_bn  708 non-null    float64
#  2   Country           708 non-null    object
#  3   City              699 non-null    object
#  4   Industry          708 non-null    object
#  5   Investors         707 non-null    object
#  6   Year_founded      708 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 38.8+ KB

# %%
unicorns.sample(5)
# Out:
#           Company_name  Valuation_usd_bn        Country           City  \
# 54              Ziroom               6.6          China        Beijing
# 252          BlaBlaCar               2.0         France          Paris
# 646               Dave               1.0  United States    Los Angeles
# 383  Collective Health               1.5  United States  San Francisco
# 324     DispatchHealth               1.7  United States         Denver
#
#                             Industry  \
# 54   E-commerce & direct-to-consumer
# 252            Auto & transportation
# 646                          Fintech
# 383                          Fintech
# 324                           Health
#
#                                              Investors  Year_founded
# 54   Sequoia Capital China, Warburg Pincus, General...          2018
# 252  Accel Partners, Index Ventures, Insight Ventur...          2015
# 646     Section 32, SV Angel, Norwest Venture Partners          2019
# ...

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 56
# Health                                  55
# Other                                   50
# Supply chain, logistics, & delivery     34
# Mobile & telecommunications             34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             26
# Hardware                                23
# Edtech                                  20
# Consumer & retail                       19
# Travel                                  13
# Education                                1
# Artificial Intelligence                  1
# Healh                                    1
# Data management & analytics<             1
# Name: Industry, dtype: int64

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("Heal", "Health")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 56
# Healthth                                55
# Other                                   50
# Supply chain, logistics, & delivery     34
# Mobile & telecommunications             34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             26
# Hardware                                23
# Edtech                                  20
# Consumer & retail                       19
# Travel                                  13
# Artificial Intelligence                  1
# Healthh                                  1
# Data management & analytics<             1
# Education                                1
# Name: Industry, dtype: int64

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("Healthth", "Health")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 56
# Health                                  55
# Other                                   50
# Supply chain, logistics, & delivery     34
# Mobile & telecommunications             34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             26
# Hardware                                23
# Edtech                                  20
# Consumer & retail                       19
# Travel                                  13
# Education                                1
# Artificial Intelligence                  1
# Healthh                                  1
# Data management & analytics<             1
# Name: Industry, dtype: int64

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("Healthh", "Health")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 56
# Health                                  56
# Other                                   50
# Mobile & telecommunications             34
# Supply chain, logistics, & delivery     34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             26
# Hardware                                23
# Edtech                                  20
# Consumer & retail                       19
# Travel                                  13
# Artificial Intelligence                  1
# Data management & analytics<             1
# Education                                1
# Name: Industry, dtype: int64

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("<", "")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 56
# Health                                  56
# Other                                   50
# Mobile & telecommunications             34
# Supply chain, logistics, & delivery     34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             27
# Hardware                                23
# Edtech                                  20
# Consumer & retail                       19
# Travel                                  13
# Education                                1
# Artificial Intelligence                  1
# Name: Industry, dtype: int64

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("Education", "Edtech")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Health                                  56
# Artificial intelligence                 56
# Other                                   50
# Mobile & telecommunications             34
# Supply chain, logistics, & delivery     34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             27
# Hardware                                23
# Edtech                                  21
# Consumer & retail                       19
# Travel                                  13
# Artificial Intelligence                  1
# Name: Industry, dtype: int64

# %%
"Artificial Intelligence".lower()
# Out:
# 'artificial intelligence'

# %%
unicorns["Industry"] = unicorns.Industry.str.replace("Intelligence", "intelligence")

# %%
unicorns["Industry"].value_counts()
# Out:
# Fintech                                122
# Internet software & services           110
# E-commerce & direct-to-consumer         82
# Artificial intelligence                 57
# Health                                  56
# Other                                   50
# Mobile & telecommunications             34
# Supply chain, logistics, & delivery     34
# Auto & transportation                   31
# Cybersecurity                           29
# Data management & analytics             27
# Hardware                                23
# Edtech                                  21
# Consumer & retail                       19
# Travel                                  13
# Name: Industry, dtype: int64

# %%
unicorns["Investors"].value_counts()
# Out:
# Caffeinated Capital, Obvious Ventures, Venrock                                                 2
# SoftBank Group                                                                                 2
# Global Founders Capital, Shea Ventures, Greycroft                                              2
# General Atlantic                                                                               2
# Shunwei Capital Partners, China Media Group, Guangzhou Huiyin Aofeng Equity Investment Fund    2
#                                                                                               ..
# L Capital Partners                                                                             1
# ClalTech, Vertex Ventures, Oryzn Capital                                                       1
# TSG Consumer Partners, Crowdcube                                                               1
# Sequoia Capital China, Goldman Sachs, Matrix Partners China                                    1
# ...

# %%
unicorns.tail()
# Out:
#        Company_name  Valuation_usd_bn        Country           City  \
# 703          Shippo               1.0  United States  San Francisco
# 704  Thirty Madison               1.0  United States       New York
# 705  LetsGetChecked               1.0        Ireland         Dublin
# 706          VerbIT               1.0         Israel       Tel Aviv
# 707            Aura               1.0  United States     Burlington
#
#                                 Industry  \
# 703  Supply chain, logistics, & delivery
# 704                               Health
# 705                               Health
# 706              Artificial intelligence
# 707                        Cybersecurity
#
#                                              Investors  Year_founded
# 703  Version One Ventures, Uncork Capital, Bessemer...          2021
# 704  Northzone Ventures, Maveron, Johnson & Johnson...          2021
# 705  Optum Ventures, Qiming Venture Partners, Trans...          2021
# ...

# %% [markdown]
# ### After preparing and cleaning the initial dataset I will no enrich it via web scrapping

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url_dr = "https://app.dealroom.co/companies"

# %%
url_dr + "/klarna"
# Out:
# 'https://app.dealroom.co/companies/klarna'

# %%
response_1 = requests.get(url_dr)

# %%
response_1.status_code
# Out:
# 200

# %%
response_1.content
# Out:
# b'\n    <!doctype html>\n    <html lang="en">\n      <head>\n      <meta charset="UTF-8">\n      <link rel="preconnect" crossorigin href="https://api.dealroom.co/">\n      <link rel="preconnect" crossorigin href="https://s3-eu-west-1.amazonaws.com">\n      <link rel="preload" as="font" type="font/woff2" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v11/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7lujVj9w.woff2">\n        <link rel="modulepreload" href="/initialization.a8c63750ff72428b7c04.js">\n        <link href=\'/initialization.a8c63750ff72428b7c04.css\' rel="stylesheet"   >\n<link href=\'/main.15efe154021ab722c920.css\' rel="stylesheet"   >\n        <title data-rh="true">Companies | Dealroom.co</title>\n<meta data-rh="true" name="theme-color" content=""/><meta data-rh="true" property="og:type" content="website"/><meta data-rh="true" property="og:url" content="https://app.dealroom.co/companies"/><meta data-rh="true" name="description" content="Venture capital database"
# ...

# %%
url_list_dr = []

# %%
company_list = list(unicorns["Company_name"])

# %%
for c in company_list:
    company_url = url_dr + f"/{c}"
    url_list_dr.append(company_url)

# %%
url_list_dr
# Out:
# ['https://app.dealroom.co/companies/Bytedance',
#  'https://app.dealroom.co/companies/Stripe',
#  'https://app.dealroom.co/companies/SpaceX',
#  'https://app.dealroom.co/companies/Didi Chuxing',
#  'https://app.dealroom.co/companies/Klarna',
#  'https://app.dealroom.co/companies/Instacart',
#  'https://app.dealroom.co/companies/Nubank',
#  'https://app.dealroom.co/companies/Epic Games',
#  'https://app.dealroom.co/companies/Databricks',
#  'https://app.dealroom.co/companies/Rivian',
#  "https://app.dealroom.co/companies/BYJU's",
#  'https://app.dealroom.co/companies/One97 Communications',
#  'https://app.dealroom.co/companies/Yuanfudao',
#  'https://app.dealroom.co/companies/DJI Innovations',
#  'https://app.dealroom.co/companies/Canva',
#  'https://app.dealroom.co/companies/SHEIN',
#  'https://app.dealroom.co/companies/Checkout.com',
#  'https://app.dealroom.co/companies/Chime',
#  'https://app.dealroom.co/companies/Grab',
#  'https://app.dealroom.co/companies/Plaid Technologies',
# ...

# %%
url_test = "https://app.dealroom.co/companies/aura"

# %%
response_2 = requests.get(url_test)

# %%
response_2.status_code
# Out:
# 200

# %%
response_2.content
# Out:
# b'\n    <!doctype html>\n    <html lang="en">\n      <head>\n      <meta charset="UTF-8">\n      <link rel="preconnect" crossorigin href="https://api.dealroom.co/">\n      <link rel="preconnect" crossorigin href="https://s3-eu-west-1.amazonaws.com">\n      <link rel="preload" as="font" type="font/woff2" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v11/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7lujVj9w.woff2">\n        <link rel="modulepreload" href="/initialization.a8c63750ff72428b7c04.js">\n        <link href=\'/initialization.a8c63750ff72428b7c04.css\' rel="stylesheet"   >\n<link href=\'/main.15efe154021ab722c920.css\' rel="stylesheet"   >\n        <title data-rh="true">Aura company information, funding &amp; investors | Dealroom.co</title>\n<meta data-rh="true" name="theme-color" content=""/><meta data-rh="true" property="og:type" content="website"/><meta data-rh="true" name="apple-mobile-web-app-capable" content="yes"/><meta data-rh="true" name="apple-mobile-web-ap
# ...

# %% [markdown]
# ### I have tried some url's for companies with spaces in the names and mostly the web shows no result, as it converts spaces into _ In order to minimize errors, I will now substitute blank spaces in the company name column for _

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace(" ", "_")

# %%
unicorns.head()
# Out:
#    Company_name  Valuation_usd_bn        Country           City  \
# 0     Bytedance             140.0          China        Beijing
# 1        Stripe              95.0  United States  San Francisco
# 2        SpaceX              74.0  United States      Hawthorne
# 3  Didi_Chuxing              62.0          China        Beijing
# 4        Klarna              45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded
# 0          2017
# 1          2014
# 2          2012
# 3          2015
# 4          2011

# %%
company_list_1 = list(unicorns["Company_name"])

# %%
url_list_dr_1 = []

# %%
for c in company_list_1:
    company_url = url_dr + f"/{c}"
    url_list_dr_1.append(company_url)

# %%
url_list_dr_1
# Out:
# ['https://app.dealroom.co/companies/Bytedance',
#  'https://app.dealroom.co/companies/Stripe',
#  'https://app.dealroom.co/companies/SpaceX',
#  'https://app.dealroom.co/companies/Didi_Chuxing',
#  'https://app.dealroom.co/companies/Klarna',
#  'https://app.dealroom.co/companies/Instacart',
#  'https://app.dealroom.co/companies/Nubank',
#  'https://app.dealroom.co/companies/Epic_Games',
#  'https://app.dealroom.co/companies/Databricks',
#  'https://app.dealroom.co/companies/Rivian',
#  "https://app.dealroom.co/companies/BYJU's",
#  'https://app.dealroom.co/companies/One97_Communications',
#  'https://app.dealroom.co/companies/Yuanfudao',
#  'https://app.dealroom.co/companies/DJI_Innovations',
#  'https://app.dealroom.co/companies/Canva',
#  'https://app.dealroom.co/companies/SHEIN',
#  'https://app.dealroom.co/companies/Checkout.com',
#  'https://app.dealroom.co/companies/Chime',
#  'https://app.dealroom.co/companies/Grab',
#  'https://app.dealroom.co/companies/Plaid_Technologies',
# ...

# %% [markdown]
# ### I am going to test with one URL if I can get the value I need

# %%
url_test_2 = "https://app.dealroom.co/companies/bytedance"

# %%
response_3 = requests.get(url_test_2)

# %%
response_3.status_code
# Out:
# 200

# %% [markdown]
# ### I've had some trouble finding the same html code in the ".content", looking in google I found that the below code works out and provides an output with the tag I need to scrap the data I want

# %%
soup_1 = BeautifulSoup(response_3.text, 'html.parser')

# %%
soup_1
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link crossorigin="" href="https://api.dealroom.co/" rel="preconnect"/>
# <link crossorigin="" href="https://s3-eu-west-1.amazonaws.com" rel="preconnect"/>
# <link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/sourcesanspro/v11/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7lujVj9w.woff2" rel="preload" type="font/woff2"/>
# <link href="/initialization.a8c63750ff72428b7c04.js" rel="modulepreload"/>
# <link href="/initialization.a8c63750ff72428b7c04.css" rel="stylesheet"/>
# <link href="/main.15efe154021ab722c920.css" rel="stylesheet"/>
# <title data-rh="true">ByteDance company information, funding &amp; investors | Dealroom.co</title>
# ...

# %%
len(soup_1.find_all("span"))
# Out:
# 236

# %%
soup_1.find_all(
    name="span",
    class_="tooltip-target"
)
# Out:
# [<span class="tooltip-target">€3.8b</span>]

# %%
total_funding = (soup_1.find_all(
    name="span",
    class_="tooltip-target"
)[0].text)

# %%
total_funding
# Out:
# '€3.8b'

# %% [markdown]
# ### This value refers to the total funding raised by the startup, and is the data I am going to scrap for every company I have in the dataset

# %% [markdown]
# ### I have realised I need to make an adjustment to the company_name column so that all names are in lower case, this is to fit the format of the url

# %%
def lower_case(x):
    return x.lower()

# %%
unicorns["Company_name"] = unicorns["Company_name"].apply(lower_case)

# %%
unicorns.head()
# Out:
#    Company_name  Valuation_usd_bn        Country           City  \
# 0     bytedance             140.0          China        Beijing
# 1        stripe              95.0  United States  San Francisco
# 2        spacex              74.0  United States      Hawthorne
# 3  didi_chuxing              62.0          China        Beijing
# 4        klarna              45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded
# 0          2017
# 1          2014
# 2          2012
# 3          2015
# 4          2011

# %%
company_list_1 = list(unicorns["Company_name"])

# %%
url_list_dr_2 = []

# %%
for c in company_list_1:
    company_url = url_dr + f"/{c}"
    url_list_dr_2.append(company_url)

# %%
url_list_dr_2
# Out:
# ['https://app.dealroom.co/companies/bytedance',
#  'https://app.dealroom.co/companies/stripe',
#  'https://app.dealroom.co/companies/spacex',
#  'https://app.dealroom.co/companies/didi_chuxing',
#  'https://app.dealroom.co/companies/klarna',
#  'https://app.dealroom.co/companies/instacart',
#  'https://app.dealroom.co/companies/nubank',
#  'https://app.dealroom.co/companies/epic_games',
#  'https://app.dealroom.co/companies/databricks',
#  'https://app.dealroom.co/companies/rivian',
#  "https://app.dealroom.co/companies/byju's",
#  'https://app.dealroom.co/companies/one97_communications',
#  'https://app.dealroom.co/companies/yuanfudao',
#  'https://app.dealroom.co/companies/dji_innovations',
#  'https://app.dealroom.co/companies/canva',
#  'https://app.dealroom.co/companies/shein',
#  'https://app.dealroom.co/companies/checkout.com',
#  'https://app.dealroom.co/companies/chime',
#  'https://app.dealroom.co/companies/grab',
#  'https://app.dealroom.co/companies/plaid_technologies',
# ...

# %%
len(url_list_dr_2)
# Out:
# 708

# %%
startup_funding = []

# %%
startup_funding
# Out:
# []

# %%
len(startup_funding)
# Out:
# 0

# %%
def obtain_funding(u):
    response = requests.get(u)
    soup = BeautifulSoup(response.text, 'html.parser')
    company_funding = (soup.find_all(name="span", class_="tooltip-target")[0].text)
    return company_funding

# %%
obtain_funding("https://app.dealroom.co/companies/yuanfudao")
# Out:
# '€3.4b'

# %%
for u in url_list_dr_2:
    try:
        total_funding = obtain_funding(u)
        startup_funding.append(total_funding)
    except:
        startup_funding.append("funding not available")

# %%
startup_funding
# Out:
# ['€3.8b',
#  '€2.3b',
#  '€5.1b',
#  'funding not available',
#  '€3.1b',
#  '€2.4b',
#  '€2.1b',
#  'funding not available',
#  '€1.7b',
#  'funding not available',
#  'funding not available',
#  'funding not available',
#  '€3.4b',
#  'funding not available',
#  '€335m',
#  '€497m',
#  'funding not available',
#  '€39.8m',
#  '€12.3b',
#  'funding not available',
#  '€2.1b',
#  '€2.4b',
#  'funding not available',
#  '€3.3b',
#  'funding not available',
#  'funding not available',
#  '€2.9b',
#  '-',
#  '€1.2b',
#  '€1.5k',
#  '€2.3b',
#  '€266m',
#  '€506m',
#  '€617m',
#  '€1.6b',
#  '€4.0b',
#  '€732m',
#  '€3.3b',
#  '€3.2b',
#  '€2.1b',
#  'funding not available',
#  'funding not available',
#  'funding not available',
#  '€924m',
#  '€968m',
#  'funding not available',
#  '€762m',
#  '€3.3b',
#  '€2.7m',
#  '-',
#  '€436m',
#  '€548m',
#  'funding not available',
#  '€764m',
#  '€1.0b',
#  'funding not available',
#  '-',
#  'funding not available',
# ...

# %%
len(startup_funding)
# Out:
# 708

# %% [markdown]
# ### I have now extracted a list of total funding for each startup, it seem that there are some not available but this can be do to the name tag of the startup in the URL. I will spend some time to fix the URL's manually in those cases where it didn't work

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("verbit", "verbit_ai")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("letsgetchecked", "letsgetchecked_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("printful", "printful_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("vise", "vice_media")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("amount", "amount_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("forte", "")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("honeybook", "honeybook_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("firefly_aerospace", "firefly_space_systems")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("mux", "mux_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("evidation_health", "evidation")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("qua_security", "aquasecurity")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("infra.market", "infra_market")
# Out:
# <ipython-input-106-404ee89b5ecf>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("infra.market", "infra_market")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("splashtop", "splashtop_inc")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("sennder", "sender")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("dailyhunt", "dailyhunt_vers_innovation_pvt_ltd_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("dave", "dave_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("boom_supersonic", "boom_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("eightfold.ai", "eightfold")
# Out:
# <ipython-input-112-12d4dee75beb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("eightfold.ai", "eightfold")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("innovium", "innovium_inc")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("lilium_aviation", "lilium")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("bright_healthcare", "bright_health")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("pendo", "pendo_io")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ola_electric_mobility", "ola")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("knowbox", "beijing_zhishi_yinxiang_co_ltd_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ocsial", "ocsial_group")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("reef_technology", "parkjockey")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("geek+", "geek_")
# Out:
# <ipython-input-121-eb34ba9d6c9e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("geek+", "geek_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("bitfury", "bitfury_group")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("terminus_technology", "terminus_technologies")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("omio", "goeuro")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("momenta", "momenta_global")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("linkdoc_technology", "linkdoc")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("orbbec_technology", "orbbec")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("dxy.cn", "dxy")
# Out:
# <ipython-input-128-d56d52146319>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("dxy.cn", "dxy")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("yh_global", "th_global")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("mobvoi", "mobvoi_inc_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("58_daojia", "58_daojia_inc_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("mia.com", "mia_com")
# Out:
# <ipython-input-132-7c0ca98e4457>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("mia.com", "mia_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("benevolentai", "benevolent")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("leap_motor", "leapmotor")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("orcam_technologies", "orcam")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("hesai_tech", "hesai")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("rubicon_global", "rubicon_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("nxin", "nginx")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ginger", "ginger_payments")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("pharmapacks", "pharmapacks_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("getyourguide", "get_your_guide")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("tangome", "tango")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("teld", "teld_new_energy")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("deposit_solutions", "deposit_solutions_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("mininglamp_technology", "mininglamp")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("l&p_cosmetic", "l_p_cosmetic")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("cava_group", "cava_grill")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("pilot.com", "pilot_3")
# Out:
# <ipython-input-148-bc86d99c032e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("pilot.com", "pilot_3")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("judo_bank", "judo_capital")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("galaxyspace", "galaxy_space")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("rec_room", "against_gravity")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("keeptruckin", "keep_truckin")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("starry", "starry_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("everly_health", "pwnhealth")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("you_&_mr_jones", "you_amp_mr_jones")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("zeta_global", "zeta_interactive")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("melio", "melio_es")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("klook", "klook_travel")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("veepee", "vente_privee_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("chargebee_technologies", "chargebee")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("astranis_space_technologies", "astranis")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("away", "away_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("koudai", "koudai_gouwu")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("brii_biosciences", "brii_bio")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ledger", "ledger_wallet")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("id.me", "id_me")
# Out:
# <ipython-input-166-2337e2fdb5ed>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("id.me", "id_me")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("enfusion", "enfusion_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("color", "color_genomics_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("olive", "olive_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("podium", "podium_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("lenskart", "lenskart_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("xiaozhu", "xiaozhu_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("gett", "gettaxi")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("mofang_living", "_130")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ximalaya_fm", "ximalaya")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("baiwang", "baiwang_cloud")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("extend", "extend_enterprises")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("caocao", "cao_cao")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("xant", "xant_ai")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("dispatchhealth", "dispatch_health")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("carta", "eshares")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("harry's_razor_company", "harry_s")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("anduril", "anduril_industries")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("monday.com", "monday_com")
# Out:
# <ipython-input-184-2d27d0321e3b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("monday.com", "monday_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("edaili", "ebroker_1_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("urban_company", "urbanclap")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("clearco", "clearbanc")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("atai_life_sciences", "atai_life_sciences_ag")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("xingyun_b2b", "xyb2b_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("notion_labs", "notion_so")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("calm", "calm_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("quanergy_systems", "quanergy")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("tubatu.com", "to8to")
# Out:
# <ipython-input-193-a7106cb23dd8>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("tubatu.com", "to8to")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("trendy_group_international", "trendy_international_group")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("webflow", "myfavtunes")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("huaqin_telecom_technology", "huaqin_communication_technology")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("planet_labs", "planet_2")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("zume", "zume_pizza")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("toss", "viva_republica")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("sprinklr", "sprinklr_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("convoy", "convoy_2")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("weee!", "weee_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("oaknorth", "oaknorth_bank")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("bird_rides", "bird")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("flixmobility", "flixbus")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("wildlife_studios", "wildlife")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("horizon_robotics", "horizon_robotics_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("xiaohongshu", "red_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("yixia", "yixia_technology")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("highradius", "highradius_corporation")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("figure_technologies", "figure_2")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("weride", "weride_ai")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("cloudwalk", "cloudwalk_technology")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("n26", "number26")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("indigo_ag", "indigo")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("otto_bock_healthcare", "otto_bock_healthcare_india_pvt_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("relativity", "kcura")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("clubhouse", "clubhouse_app")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("yello_mobile", "yello_mobile_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("relativity_space", "relativity_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("bolt", "taxify")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ubtech_robotics", "ubtech")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("meizu_technology", "meizu")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("krafton_game_union", "bluehole_studio")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("hello_transtech", "_hellobike_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("blockchain.com", "blockchain")
# Out:
# <ipython-input-226-5202730df4cc>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("blockchain.com", "blockchain")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("pony.ai", "pony_ai")
# Out:
# <ipython-input-227-1fd8c6da03a5>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("pony.ai", "pony_ai")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("lianjia", "lianjia_home_link_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("better.com", "better_mortgage")
# Out:
# <ipython-input-229-304b6ec0d5e6>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("better.com", "better_mortgage")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("yuanqi_senlin", "genki_forest")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("reddit", "cs3")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("samsara_networks", "samsara")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("ola_cabs", "ola")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("national_stock_exchange_of_india", "national_stock_exchange")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("faire", "faire_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("xingsheng_selected", "xingsheng_youxuan")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("tempus", "tempus_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("servicetitan", "servicetitan_inc_")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("biosplice_therapeutics", "samumed")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("bitmain_technologies", "bitmain")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("juul_labs", "juul")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("plaid_technologies", "plaid_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("checkout.com", "checkout_com")
# Out:
# <ipython-input-243-3b7c568a2b19>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   unicorns["Company_name"] = unicorns.Company_name.str.replace("checkout.com", "checkout_com")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("dji_innovations", "dji")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("one97_communications", "one97")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("rivian", "rivian_automotive")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("epic_games", "epic_games_1")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("byju's", "byju_s")

# %%
unicorns["Company_name"] = unicorns.Company_name.str.replace("didi_chuxing", "didi_didi_dache")

# %%
unicorns.sample(5)
# Out:
#     Company_name  Valuation_usd_bn        Country           City  \
# 522      jiuxian              1.05          China        Beijing
# 366  xiaozhu_com              1.50          China        Beijing
# 593       ynsect              1.00         France           Evry
# 319      eshares              1.70  United States  San Francisco
# 155  sentinelone              3.10  United States  Mountain View
#
#                             Industry  \
# 522  E-commerce & direct-to-consumer
# 366                           Travel
# 593                            Other
# 319                          Fintech
# 155                    Cybersecurity
#
#                                              Investors  Year_founded
# 522  Sequoia Capital China, Rich Land Capital, Merr...          2015
# 366   Morningside Ventures, Capital Today, JOY Capital          2017
# 593  Astanor Ventures, Upfront Ventures, IDInvest P...          2019
# ...

# %%
company_list_2 = list(unicorns["Company_name"])

# %%
url_list_dr_3 = []

# %%
for c in company_list_2:
    company_url = url_dr + f"/{c}"
    url_list_dr_3.append(company_url)

# %%
unicorn_funding = []

# %%
for u in url_list_dr_3:
    try:
        total_funding = obtain_funding(u)
        unicorn_funding.append(total_funding)
    except:
        unicorn_funding.append("funding not available")

# %%
unicorn_funding
# Out:
# ['€3.8b',
#  '€2.3b',
#  '€5.1b',
#  '€18.3b',
#  '€3.1b',
#  '€2.4b',
#  '€2.1b',
#  '€4.0b',
#  '€1.7b',
#  '€7.7b',
#  '€2.4b',
#  '€2.7b',
#  '€3.4b',
#  '€95.5m',
#  '€335m',
#  '€497m',
#  '€755m',
#  '€39.8m',
#  '€12.3b',
#  '€668m',
#  '€2.1b',
#  '€2.4b',
#  '€988m',
#  '€3.3b',
#  '€695m',
#  '€707m',
#  '€2.9b',
#  '-',
#  '€1.2b',
#  '€1.5k',
#  '€2.3b',
#  '€266m',
#  '€506m',
#  '€617m',
#  '€1.6b',
#  '€4.0b',
#  '€732m',
#  '€3.3b',
#  '€3.2b',
#  '€2.1b',
#  '€835m',
#  '€745m',
#  '€3.5b',
#  '€924m',
#  '€968m',
#  'funding not available',
#  '€762m',
#  '€3.3b',
#  '€2.7m',
#  '-',
#  '€436m',
#  '€548m',
#  '€633m',
#  '€764m',
#  '€1.0b',
#  '-',
#  '-',
#  '€2.9b',
#  '€845m',
#  '€447m',
#  '€727m',
#  '€394m',
#  '€18.8m',
#  '€1.1b',
#  '€1.9b',
#  '€786m',
#  '€2.9b',
#  '€561m',
#  '€882m',
#  '€520m',
#  '€836m',
#  '€1.5b',
#  '-',
#  '€767m',
#  '€445m',
#  '€317m',
#  '€836m',
#  '€10.8m',
#  '€413m',
#  '€1.3b',
#  '€2.2b',
#  '€455m',
#  '€579m',
# ...

# %%
len(unicorn_funding)
# Out:
# 708

# %% [markdown]
# ### I had to amend several objects within the company_name column so that the url would be the correct one to obtain the corresponding data from the scraping into deal room

# %% [markdown]
# ### Given that the list has the same length as the unicorns dataset and is in the same order, I will add the list unicorn_funding as a new column

# %%
unicorns["Total_funding"] = unicorn_funding

# %%
unicorns.sample(5)
# Out:
#            Company_name  Valuation_usd_bn         Country           City  \
# 335               monzo              1.61  United Kingdom         London
# 705  letsgetchecked_com              1.00         Ireland         Dublin
# 384           handshake              1.50   United States  San Francisco
# 10               byju_s             16.50           India      Bengaluru
# 152           huitongda              3.18           China        Nanjing
#
#                             Industry  \
# 335                          Fintech
# 705                           Health
# 384     Internet software & services
# 10                            Edtech
# 152  E-commerce & direct-to-consumer
#
#                                              Investors  Year_founded  \
# 335  Passion Capital, Thrive Capital, Orange Digita...          2018
# 705  Optum Ventures, Qiming Venture Partners, Trans...          2021
# 384  Kleiner Perkins Caufield & Byers, Lightspeed V...          2021
# ...

# %%
"€3.8b".replace("€","")
# Out:
# '3.8b'

# %%
"3.8b".replace("b","")
# Out:
# '3.8'

# %%
def funding_normalizer(x):
    if "b" in x:
        y = x.replace("b", "")
        if "€" not in y:
            return("Not available")
        else:
            z = y.replace("€", "")
            return float(z)*1000
    elif "m" in x:
        y = x.replace("€", "")
        z = y.replace("m", "")
        return float(z)
    elif "k" in x:
        y = x.replace("€", "")
        z = y.replace("k", "")
        return float(z)/1000
    else:
        return("Not available")

# %%
funding_normalizer("€900k")
# Out:
# 0.9

# %%
funding_normalizer("€900m")
# Out:
# 900.0

# %%
funding_normalizer("€2b")
# Out:
# 2000.0

# %%
funding_normalizer("funding not available")
# Out:
# 'Not available'

# %%
unicorns["Total_funding"] = unicorns["Total_funding"].apply(funding_normalizer)

# %%
unicorns.head()
# Out:
#       Company_name  Valuation_usd_bn        Country           City  \
# 0        bytedance             140.0          China        Beijing
# 1           stripe              95.0  United States  San Francisco
# 2           spacex              74.0  United States      Hawthorne
# 3  didi_didi_dache              62.0          China        Beijing
# 4           klarna              45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded Total_funding
# 0          2017        3800.0
# 1          2014        2300.0
# ...

# %%
unicorns["Total_funding_€m"] = unicorns["Total_funding"]

# %%
unicorns.head()
# Out:
#       Company_name  Valuation_usd_bn        Country           City  \
# 0        bytedance             140.0          China        Beijing
# 1           stripe              95.0  United States  San Francisco
# 2           spacex              74.0  United States      Hawthorne
# 3  didi_didi_dache              62.0          China        Beijing
# 4           klarna              45.6         Sweden      Stockholm
#
#                   Industry                                          Investors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 2                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3    Auto & transportation  Matrix Partners, Tiger Global Management, Soft...
# 4                  Fintech  Institutional Venture Partners, Sequoia Capita...
#
#    Year_founded Total_funding Total_funding_€m
# ...

# %%
unicorns.drop(["Total_funding"], axis = 1, inplace = True)

# %%
unicorns.sample(5)
# Out:
#     Company_name  Valuation_usd_bn        Country       City  \
# 641       cars24               1.0          India    Gurgaon
# 673    evidation               1.0  United States  San Mateo
# 615     kk_group               1.0          China   Dongguan
# 45   j&t_express               7.8      Indonesia    Jakarta
# 620    classpass               1.0  United States   New York
#
#                                 Industry  \
# 641      E-commerce & direct-to-consumer
# 673                               Health
# 615      E-commerce & direct-to-consumer
# 45   Supply chain, logistics, & delivery
# 620         Internet software & services
#
#                                              Investors  Year_founded  \
# 641      Moore Strategic Ventures, DST Global, Unbound          2020
# 673   B Capital Group,, GE Ventures, McKesson Ventures          2021
# 615  Matrix Partners China, Bright Venture Capita, ...          2019
# ...

# %% [markdown]
# #### A partir de este nuevo data frame, voy a crear el notebook analysis. Guardo este nuevo data frame como csv para poder importarlo

# %%
unicorns.to_csv('Cleaned_unicorns.csv')
